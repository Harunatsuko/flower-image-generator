# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from flower import Flower

# %%
level_cnt = np.random.randint(2,7)
flower = Flower(500,40,levels_cnt=level_cnt, fill_type='center')
petal_kinds = [np.random.randint(1,9) for i in range(level_cnt)]
# grad colors may be 'hot', 'pink', 'green', 'cold' for example
flower.draw(grad_colors='cold')
img = flower.img*255
img = np.float32(img)
plt.figure(figsize=(8, 8))
plt.imshow(flower.img)
